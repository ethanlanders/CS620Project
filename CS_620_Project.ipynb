# %% [markdown]
# <a href="https://colab.research.google.com/github/ethanlanders/Walkability-And-Well-Being-Analysis-CS620/blob/main/CS_620_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **✅Walkability and Well-Being: An Urban Analysis**
# > *by*\
# | Ethan Landers | eland007@odu.edu | [ethanlanders.github.io](https://ethanlanders.github.io) |\
# | Lynell Freeman | lfree005@odu.edu | [lynellfreeman.github.io](https://lynellfreeman.github.io) |\
# | Dipendra Thapa Magar | dthap001@odu.edu | [dipendrathapamagar.github.io](https://dipendrathapamagar.github.io) |
#
# -------
#
# Click [here](https://github.com/ethanlanders/Walkability-And-Well-Being-Analysis-CS620#libraries) for the project GitHub Repository
#
# -------
#
# *Legend*
#
# ✅ *ready*\
# 🚧 *in progress*\
# ❌ *not yet started*

# %% [markdown]
# # ❌Presentation Video

# %%
# Presentation Video

# from IPython.display import YouTubeVideo
# YouTubeVideo('Uh8Nrf_vOUM')

# %% [markdown]
# # ✅Abstract
# ------------------------------
# In the United States, many individuals reside in communities that lack walkability, heavily relying on their cars for daily activities such as work, grocery shopping, and social interactions. This is in stark contrast to numerous regions around the world that prioritize pedestrian-friendly environments. Our project aims to investigate whether there is a relationship between community walkability and various facets of well-being, including mental health, poverty rates, access to healthcare, and more. The central objective is to discern potential correlations between walkable communities and overall happiness. <br><br>
# To achieve this, we are gathering data on walkability and related happiness indicators from New York City and conducting a detailed comparative analysis across urban neighborhoods. We seek to uncover patterns and connections that may suggest whether walkable communities contribute to increased happiness like lower rates of obesity and poverty. It's important to note that our research is ongoing, and definitive conclusions have not yet been reached. <br><br>
# The outcomes of this analysis can provide valuable insights into the urban factors that influence our overall well-being. These findings will lay a strong foundation for urban planning and policy initiatives aimed at enhancing community satisfaction and overall quality of life.

# %% [markdown]
# ## ✅End Goal
# * Establish correlation between walkable communities and happiness
# * Provide insight for individuals in urban planning and policy making

# %% [markdown]
# ##🚧Project Plan/Gannt Chart🚧
# Click [here](https://docs.google.com/spreadsheets/d/1TWXTR2F9_unp_fiDn8fJgvMIFM-rPqc7UnaDy8P5uqY/edit#gid=2140549662) to access our project's Gannt Chart *(in progress)*
# <br>*Add screenshot*

# %% [markdown]
# ## ✅Team Member Contribution Plan
#
# ### **Ethan Landers**
# * Data processing
# * Data visualization utilizing Matplotlib
# * Writing
#
# ### **Lynell Freeman**
# * Data cleanup utilizing OpenRefine
# * Writing
#
# ### **Dipendra Thapa Magar**
# * Writing

# %% [markdown]
# # ✅Introduction
# ----------------

# %% [markdown]
# The modern urban environment has a profound impact on the well-being of its inhabitants. One key aspect that often goes overlooked is the walkability of a community. Walkability not only affects physical health but also has broader implications for mental health, access to resources, and overall quality of life. This project aims to explore the relationship between community walkability and various facets of well-being, focusing on New York City as a case study. We seek to answer the research question: "Is there a relationship between community walkability and facets of well-being such as mental and physical health, poverty rates, and access to healthcare?"

# %% [markdown]
# # ✅Methods
# --------------------
#
# To address the research question, we will employ a multi-faceted approach:
#
# 1. **Data Collection**:
#
#   * Walkability data for New York City neighborhoods was sourced from publicly available datasets.
#
#   * As of now, data covering aspects as poverty rates and  obesity rates among young children per New York City neighborhood have been collected to serve as indicators of community well-being and happiness.
#
# 2. **Data Preprocessing**:
#
#   * Each dataset was cleaned and filtered to focus on relevant metrics like the most recent year's data.
#
#   * Irrelevant columns from each dataset will be removed as well.
#
# 3. **Data Analysis**:
#
#   * The datasets will be merged into one DataFrame to compare walkability data with happiness data row-by-row to determine trends.
#
# 4. **Data Visualization**:
#
#   * Various plots and charts will be generated to visualize the original datasets and the relationships between them.
#
#
# 5. **Interpretations**:
#
#   * The correlation results will be interpreted to understand the implications for urban planning and policy-making.

# %% [markdown]
# ### ✅Languages, Libraries, Tools, and Software
#
# **IDE**:<br>
# Google Colab
#   - For its exploratory data analysis, data visualization, and documentation tools, given its ease of use, collaborative features, and no-setup requirement.
#
# <br>**Language**:<br>
# Python
#   - The primary programming language due to its extensive libraries and frameworks for data analysis.
#
# <br>**Libraries**:<br>
# Pandas
#   - For data manipulation and analysis<br>
#
# Matplotlib
#   - For data visualization
#
# <br>**Tools & Software**:<br>
#
# OpenRefine
#   - Provides a user-friendly interface for exploring large datasets and applying transformations to clean and standardize the data, which is a fundamental step before any analysis or visualization.
#
# GitHub
#   - This platform is indispensable for maintaining a structured, version-controlled environment where multiple contributors can work in tandem, review code, and track changes over time. It provides a centralized platform for hosting code, documentation, and related files, enabling seamless collaboration among team members.

# %% [markdown]
# ## ✅ Walkability Index Dataset
#
# This is our primary dataset, which was obtained from [here](https://a816-dohbesp.nyc.gov/IndicatorPublic/beta/data-explorer/walking-driving-and-cycling/?id=2133#display=summary).  The dataset scores the walkability of most New York City neighbhorhoods from -3 to 9 as of 2011.  We will compare each neighborhood listed in this dataset for walkability with the same neighborhoods listed in other happiness index datasets to find correlations and trends.

# %% [markdown]
# ### ✅ Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data into .csv
df1 = pd.read_csv('https://raw.githubusercontent.com/ethanlanders/Walkability-And-Well-Being-Analysis-CS620/main/Datasets/Walkability%20Index/NYC%20EH%20Data%20Portal%20-%20Walkability%20index%20(filtered).csv')

# Rename columns for clarity
df1.rename(columns={'Score': 'Walkability Score', 'Geography': "NYC Neighborhood"}, inplace=True)

# Modify score column, which currently ranges from -3 to 9, to 0 to 13
df1['Walkability Score'] += 4

# Sort dataframe from highest walkability to lowest walkability for visualization.
sorted_df1 = df1.sort_values(by='Walkability Score', ascending=True)

# Create diagram
plt.figure(figsize=(10, 7))

# Histogram
plt.subplot(1, 2, 1)
plt.barh(sorted_df1['NYC Neighborhood'], sorted_df1['Walkability Score'], color='blue', alpha=0.7)
plt.xlabel('Walkability Score')
plt.ylabel('Neighborhood')
plt.title('Distribution of Walkability Scores Across NYC Neighborhoods')

# Boxplot
plt.subplot(1, 2, 2)
sorted_df1.boxplot(column='Walkability Score')
plt.title("New York Walkability - Boxplot")

# Output the plots
plt.tight_layout()
plt.show()

# Save the modified data frame to a new .csv file
df1.to_csv('df1_modified.csv', index=False)

# %% [markdown]
# ### ✅Data Cleansing
#
# We utilized the software 'Open Refine' to process and cleanse the dataset. The initial step involved eliminating superfluous headers and column details to ensure the dataset's readiness for Pandas's DatFrames, for later visualization. Subsequently, employing GEL commands, we separated (or expanded) the row cell data into distinct column headers. As a concluding step, it was essential to retitle these newly created headers to align with the additional information introduced.

# %% [markdown]
# ### ✅Objective
#
# This visualization is a combination of a bar chart and a box plot, which is intended to visually convey the information contained in the dataset about the walkability of various neighborhoods in New York City. The bar chart on the left lists neighborhoods in descending order of walkability score from highest to lowest, while the box plot on the right provides a statistical summary of the walkability scores across all the neighborhoods.
#
# In the bar chart, each neighborhood's walkability is represented by the length of the horizontal bars. A longer bar indicates a higher walkability score, which suggests that the neighborhood is more pedestrian-friendly.
#
# On the right side, the box plot provides a summary of the walkability scores based on several criterion:
#
# 1. **Minimum**: The lowest walkability score, not including outliers.
#
# 2. **First Quartile**: The score below which 25% of the neighborhoods fall.
#
# 3. **Median** (indicated by the line within the box): The middle value of the walkability scores.
#
# 4. **Third Quartile**: The score below which 75% of the neighborhoods fall.
#
# 5. **Maximum**: The higest walkability score, not including outliers.
#
# 6. **Outliers**:  The small circles on the graph represent neighborhoods with walkability scores that are unusually high compared with the rest of the data.
#
# The objective of the bar chart is to provide a clear and comparative visualization of how walkable different neighborhoods are in New York City. The box plot supplements this by offering a statistical overview for understanding the dataset's distribution.

# %% [markdown]
# ### ✅ Bar Chart Structure
#
#
# 1. **X-Axis**: Walkability score, ranging from 0 to 13<br>(*A longer bar indicates greater walkability*)
#
# 2. **Y-Axis**: The New York City neighborhoods surveyed within the dataset

# %% [markdown]
# ### ✅ Observations
#
# To assess the walkability of various neighborhoods in New York City based on a given metric and compare their scores.
#
#
# 1. Greenwich Village - SoHo has the *highest* walkability score observed.
#
# 2. South Beach - Tottenville has the *lowest* walkability score observed.
#
# 3. A large number of neighborhoods have scores clustered between 4 and 8, indicating a moderate level of walkability for a significant portion of the New York City.
#
# 4. The median walkability score is around 6, with 50% of the data falling between scores of approximately 4 and 8 (the interquartile range). There are also some potential outliers indicated by the small circles above the upper whisker.

# %% [markdown]
# ### ✅ Potential Implications and Further Analysis
#
#
# 1. Neighborhoods with higher walkability scores see higher foot traffic, which influences urban planning and business decisions as well as real estate values.
#
# 2. Areas with lower walkability scores might require infrastructure improvements or urban planning revisions to enhance pedestrian accessibility.  They are most likely the most car-dependent neighborhoods in New York City.
#
# 3. The outliers in the data suggest that certain neighborhoods have exceptionally high walkability scores that deviate from the general trend, warranting a closer examination of what factors contribute to their high scores.

# %% [markdown]
# ## ✅Obesity Among Public Elementary and Middle School Students
# This dataset was obtained from [here](https://data.cccnewyork.org/data/download#0,8/1224).

# %% [markdown]
# ### ✅Visualization

# %%
# Obesity_Among_Public_Elementary_and_Middle_School_Students

# Read the CSV data into a DataFrame
df2 = pd.read_csv("https://raw.githubusercontent.com/ethanlanders/CS620Project/main/Datasets/Obesity_Among_Public_Elementary_and_Middle_School_Students/Cleaned/Obesity_Among_Public_Elementary_and_Middle_School_Students_Cleaned.csv")

# Filter the data to keep only the year 2011
df2 = df2.loc[df2['TimeFrame'] == 2011]

# Define a condition to filter rows where 'DataFormat' is 'Percent' and 'TimeFrame' is 2011
condition = (df2['DataFormat'] == 'Percent') & (df2['TimeFrame'] == 2011)

# Select specific columns ('Location', 'TimeFrame', 'Data') and display the result
df2.loc[condition, ['Location', 'TimeFrame', 'Data']]

# Sort the result by the 'Data' column in ascending order
sorted_result = df2.sort_values(by='Data', ascending=False)

# Create a horizontal bar chart
plt.figure(figsize=(6, 12))
plt.barh(sorted_result['Location'], sorted_result['Data'])
plt.ylabel('NYC Neighborhood')
plt.xlabel('Percentage (%) of Obese Adolescents')
plt.title('Obesity Among Public Elementary and Middle School Students in NYC')

# Display the plot
plt.show()

# Save the filtered data to a new .csv file
df2.to_csv('df2_filtered.csv', index=False)

# %% [markdown]
# ### ✅Data Cleansing
#
# We utilized the software 'Open Refine' to process and cleanse the dataset. The initial step involved eliminating superfluous headers and column details to ensure the dataset's readiness for visualization. Subsequently, employing GEL commands, we separated (or expanded) the row cell data into distinct column headers. As a concluding step, it was essential to retitle these newly created headers to align with the additional information introduced.

# %% [markdown]
# ### ✅Objective
#
# Reading a dataset about obesity prevalence among public elementary and middle school students in different New York City neighborhoods is the goal of this chart. Only percentages from the year 2011 are shown after carefully filtering the data. The code then creates a horizontal bar chart to represent this information after sorting the data in descending order according to the obesity proportion.

# %% [markdown]
# ### ✅Structure
#
# 1. Import Libraries: Importing the required Python libraries pandas and matplotlib.pyplot.
#
# 2. Data Reading: Reading a CSV file into a Pandas DataFrame from a URL.
#
# 3. Data Filtering: Applying conditions to select only the rows where the 'Data Format' is 'Percent' and the 'Time Frame' is 2011.
#
# 4. Data Transformation: Although commented out, there is an option to convert the 'Data' column to integers.
#
# 5. Data Selection: Selecting only the relevant columns ('Location', 'Time Frame', 'Data') from the DataFrame.
#
# 6. Data Sorting: Sorting the filtered data by the 'Data' column in descending order.
#
# 7. Data Visualization: Creating a horizontal bar chart using matplotlib.pyplot.

# %% [markdown]
# ### ✅Observations
#
# 1. Data Source: The data is fetched from a GitHub repository.
#
# 2. Graphical Visualization: A horizontal bar chart is employed, making it easier to read the names of the neighborhoods.
#
# 3. Data Labels: The Y-axis represents neighborhoods, and the X-axis represents the percentage of individuals.

# %% [markdown]
# ### ✅Further Analysis
#
# 1. Time-Series Analysis: Extend the code to include data from multiple years to study trends over time.
#
# 2. Demographic Segmentation: Break down the data by other demographic factors like age, gender, etc.
#
# 3. Comparative Study: Compare obesity rates with other social or economic factors to find potential correlations.

# %% [markdown]
# ## ✅ Poor Population Living in Concentrated Poverty
# This dataset was obtained from [here](https://data.cccnewyork.org/data/download#0,8/1224).

# %% [markdown]
# ### ✅Visualization

# %%
# Poor_Population_Living_in_Concentrated_Poverty

import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV data into a DataFrame
df3 = pd.read_csv("https://raw.githubusercontent.com/ethanlanders/CS620Project/main/Datasets/Concentrated%20Poverty/Cleaned/Poor_Population_Living_in_Concentrated_Poverty_Cleaned.csv")

# Filter the DataFrame to include data only for the year 2020 (the most relevant year in dataset)
df3 = df3.loc[df3['Time Frame'] == 2020]

# Define a condition to filter rows where 'Data Format' is 'Percent' and 'Time Frame' is 2020
condition = (df3['Data Format'] == 'Percent') & (df3['Time Frame'] == 2020)

# Select specific columns ('Location', 'Time Frame', 'Data') based on the condition
df3 = df3.loc[condition, ['Location', 'Time Frame', 'Data']]

# Sort the result by the 'Data' column in descending order to visualize the highest values first
sorted_result = df3.sort_values(by='Data', ascending=False)

# Bar Chart
plt.figure(figsize=(6, 12))
plt.barh(sorted_result['Location'], sorted_result['Data'])
plt.ylabel('NYC Neighborhood')
plt.xlabel('Percentage (%) of Individuals Living in Concentrated Poverty')
plt.title('Poor Population Living in Concentrated Poverty in NYC (2020)')
plt.show()

# Save the filtered DataFrame to a new .csv file
df3.to_csv('df3.csv', index=False)

# %% [markdown]
# ### ✅ Objective
#
# Our goal was to visualize the dataset's most relevant year's data, which was 2020.  The dataset contains estimates of the number of people who live in concentrated poverty in New York City neighborhoods. We used Python's Pandas and Matplotlib libraries to filter, process, and display this dataset's data as a horizontal bar chart.

# %% [markdown]
# ### ✅ Data Reformatting
#
# The Open Refine process for cleaning this dataset involved:
#
# 1. Splitting the "Location" column into five new columns using commas as separators and removing the original column.
#
# 2. Renaming the new columns to "Location," "Time Frame," "Data Format," "Data1," and "Fips1."
#
# 3. Removing redundant columns like "TimeFrame," "DataFormat," "Data," and "Fips."
#
# 4. Renaming "Data1" and "Fips1" back to "Data" and "Fips" for consistency.
#
# 5. Applying text transformations to "Time Frame," "Data," and "Fips" columns to ensure proper formats (dates for "Time Frame," numbers for "Data" and "Fips").
#
# 6. Preserving original values in case of errors during transformations.
#
# This process ensures the dataset is clean, well-structured, and ready for subsequent data analysis operations.

# %% [markdown]
# ### ✅ Code Structure
#
# 1. Import Libraries: The code begins by importing required libraries, namely Pandas for data manipulation and Matplotlib for data visualization.
#
# 2. Read Data: The data is read from a CSV file hosted on this project's GitHub page into a DataFrame.
#
# 3. Data Filtering: A condition is set to filter the rows where the 'Data Format' is 'Number' and 'Time Frame' is '2020.'
#
# 4. Data Transformation: The 'Data' column for the selected rows is converted to integers.
#
# 5. Data Selection: Specific columns ('Location', 'Time Frame', 'Data') were selected.
#
# 6. Data Sorting: The selected data is sorted by the 'Data' column in descending order.
#
# 7. Data Visualization: A horizontal bar chart is created to display the data. Neighborhoods serve as the y-axis and the number of individuals as the x-axis

# %% [markdown]
# ### ✅ Further Analysis
#
# 1. Demographic Segmentation: Breaking down the concentrated poverty data by age, ethnicity, etc., could offer more nuanced insights.
#
# 2. Cross-Referencing Data: This data could be cross-referenced with other socioeconomic indicators to better understand the causes or impacts of concentrated poverty.

# %% [markdown]
# ## ✅Merging the Datasets

# %% [markdown]
# The provided Python code performs a comprehensive analysis of walkability, obesity rates, and poverty rates across different neighborhoods in New York City (NYC). Initially, it reads three separate CSV files into Pandas DataFrames, representing walkability, obesity data, and poverty data. The walkability DataFrame `df1` is sorted alphabetically based on NYC neighborhood names. The obesity DataFrame `df2` is filtered to retain only the data from the year 2011 and is then sorted alphabetically by location. Similarly, the poverty DataFrame `df3` is filtered to keep data from the year 2020 with a percentage data format and is sorted alphabetically by location.
#
# To enhance clarity, column names in `df2` and `df3` are renamed to 'Obesity Rate %' and 'Poverty Rate %,' respectively. Decimal values in these columns are multiplied by 100 to represent percentages. The code then creates three new DataFrames `df1_neighborhoods`, `df2_neighborhoods`, `df3_neighborhoods` to ensure that each DataFrame has the same number of rows (65).
#
# A comparison DataFrame `comparison_csv` is created to compare neighborhood names from each dataset side by side. This DataFrame is saved as a CSV file for manual inspection.
#
# Two dictionaries `map_df1_to_df2` and `map_df1_to_df3` are then created to map neighborhood names from `df1` to `df2` and `df1` to `df3`, ensuring consistency for successful merging.
#
# Two new columns `df1_to_df2_map` and `df1_to_df3_map` are added to `df1` to contain consistent neighborhood names between the three DataFrames. The code then merges the three DataFrames `df1`, `df2`, and `df3` into a new DataFrame `merged` using the mapped neighborhood names. Finally, a final DataFrame `comparison_df` is created by selecting relevant columns from the `merged` DataFrame, including NYC neighborhood names, walkability scores, obesity rates, and poverty rates. The result is printed for further analysis.

# %% [markdown]
# ### ✅Code

# %%
# Read in the .csv data into three different data frames
df2 = pd.read_csv("https://raw.githubusercontent.com/ethanlanders/Walkability-And-Well-Being-Analysis-CS620/main/Datasets/Obesity_Among_Public_Elementary_and_Middle_School_Students/Cleaned/Obesity_Among_Public_Elementary_and_Middle_School_Students_Cleaned.csv")
df3 = pd.read_csv("https://raw.githubusercontent.com/ethanlanders/Walkability-And-Well-Being-Analysis-CS620/main/Datasets/Concentrated%20Poverty/Cleaned/Poor_Population_Living_in_Concentrated_Poverty_Cleaned.csv")

# Sort df1 alphabetically
df1.sort_values(by='NYC Neighborhood', ascending=True, inplace=True)

# Keep df2's most relevant year, sort alphabetically
df2 = df2.loc[df2['TimeFrame'] == 2011]
df2.sort_values(by='Location', ascending=True, inplace=True)

# Keep df3's most relevant year, keep the perentage data format, sort alphabetically
df3 = df3.loc[df3['Time Frame'] == 2020]
df3 = df3.loc[df3['Data Format'] == "Percent"]
df3.sort_values(by='Location', ascending=True, inplace=True)

# Rename columns for clarity
df2.rename(columns={'Data': 'Obesity Rate %'}, inplace=True)
df3.rename(columns={'Data': 'Poverty Rate %'}, inplace=True)

# Multiply decimals by 100 to get understandable percentages
df2['Obesity Rate %'] = df2['Obesity Rate %'] * 100
df3['Poverty Rate %'] = df3['Poverty Rate %'] * 100

# Create new dataframes, ensuring that each data frame has the same number of rows (65)
df1_neighborhoods = list(df1['NYC Neighborhood'].unique()) + [None]*23
df2_neighborhoods = list(df2['Location'].unique()) + [None]*17
df3_neighborhoods = list(df3['Location'].unique())

# Create a new data frame to compare the neighborhood names from each dataset
# side by side to create dictionary.
comparison_csv = pd.DataFrame({'df1': df1_neighborhoods, 'df2': df2_neighborhoods, 'df3': df3_neighborhoods, })

# Download the .csv file to compare by hand
comparison_csv.to_csv('comparison.csv', index=False, encoding='utf-8')

# Dictionary to map df1 to df2
# The value on the right of the colon will replace the value on the left
# The df1 key must be maintained between this dictionary to the next one for successful merging
map_df1_to_df2 = {
    "Bayside - Little Neck": "Bayside - Little Neck",
    "Bedford Stuyvesant - Crown Heights": "Bedford Stuyvesant - Crown Heights",
    "Bensonhurst - Bay Ridge":  "Bensonhurst - Bay Ridge",
    "Borough Park":  "Borough Park",
    "Canarsie - Flatlands":   "Canarsie - Flatlands",
    "Chelsea - Clinton":  "Chelsea - Clinton",
    "Coney Island - Sheepshead Bay":  "Coney Island - Sheepshead Bay",
    "Crotona -Tremont":  "Crotona - Tremont", # DIFFERENT
    "Downtown - Heights - Slope":  "Downtown  - Heights - Slope", # DIFFERENT
    "East Flatbush - Flatbush":  "East Flatbush - Flatbush",
    "East Harlem":  "East Harlem",
    "East New York":  "East New York",
    "Flushing - Clearview":  "Flushing - Clearview",
    "Fordham - Bronx Pk": "Fordham - Bronx Park", # DIFFERENT
    "Fresh Meadows":  "Fresh Meadows",
    "Gramercy Park - Murray Hill":  "Gramercy Park - Murray Hill",
    "Greenpoint":  "Greenpoint",
    "Greenwich Village - SoHo":  "Greenwich Village - Soho", # DIFFERENT
    "Hunts Point - Mott Haven":  "Hunts Point - Mott Haven",
    "Jamaica":  "Jamaica",
    "Kingsbridge - Riverdale":  "Kingsbridge - Riverdale",
    "Long Island City - Astoria":  "Long Island City - Astoria",
    "Lower Manhattan":  "Lower Manhattan",
    "Northeast Bronx":  "Northeast Bronx",
    "Pelham - Throgs Neck":  "Pelham - Throgs Neck",
    "Port Richmond":  "Port  Richmond",
    "Ridgewood - Forest Hills":  "Ridgewood - Forest Hills",
    "Rockaways":  "Rockaway", # DIFFERENT
    "South Beach - Tottenville":  "South Beach - Tottenville",
    "Southeast Queens":  "Southeast Queens",
    "Southwest Queens":  "Southwest Queens",
    "Stapleton - St. George":  "Stapleton - St. George",
    "Sunset Park":  "Sunset Park",
    "Union Square - Lower East Side":  "Union Square - Lower East Side",
    "Upper East Side":  "Upper East Side",
    "Upper West Side":  "Upper West Side",
    "Washington Heights":  "Washington Heights - Inwood", # DIFFERENT
    "West Queens":  "West Queens",
    "Williamsburg - Bushwick":  "Williamsburg - Bushwick",
    "Willowbrook":  "Willowbrook"
}

# Dictionary to map df1 to df3
# The value on the right of the colon will replace the value on the left
# The df1 key must be maintained between this dictionary and the previous one for successful merging
# So... replace the df3 key
# Example:
# df1 contains "Bayside - Little Neck."  Keep that, replace "Bayside" from df3 with "Bayside - Little Neck"
map_df1_to_df3 = {
    "Bayside - Little Neck": "Bayside",
    "Bedford Stuyvesant - Crown Heights":  "Bedford Stuyvesant",
    "Bensonhurst - Bay Ridge":  "Bensonhurst",
    "Borough Park":  "Borough Park",
    "Canarsie - Flatlands":  "Canarsie",
    "Central Harlem - Morningside Heights":  "Central Harlem",
    "Chelsea - Clinton":  "Chelsea/Clinton",
    "Coney Island - Sheepshead Bay":  "Coney Island",
    "East Flatbush - Flatbush":  "East Flatbush",
    "East Harlem":  "East Harlem",
    "East New York":  "East New York",
    "Flushing - Clearview":  "Flushing",
    "Fresh Meadows":  "Fresh Meadows/Briarwood",
    "Greenwich Village - SoHo":  "Greenwich Village",
    "Hunts Point - Mott Haven":  "Hunts Point",
    "Jamaica":  "Jamaica/St. Albans",
    "Kingsbridge - Riverdale":  "Riverdale",
    "Long Island City - Astoria":  "Astoria",
    "Pelham - Throgs Neck":  "Pelham Parkway",
    "Ridgewood - Forest Hills": "Ridgewood/Glendale",
    "South Beach - Tottenville": "South Beach",
    "Stapleton - St. George": "St. George",
    "Sunset Park": "Sunset Park",
    "Union Square - Lower East Side": "Lower East Side",
    "Upper East Side": "Upper East Side",
    "Upper West Side": "Upper West Side",
    "Washington Heights": "Washington Heights",
    "Williamsburg - Bushwick": "Williamsburg/Greenpoint"
}

# Create two new columns which contain consistent neigborhood names between the three data frames.
# To do so, apply the dictionary keys to df1's 'Geography' column.
df1["df1_to_df2_map"] = df1['NYC Neighborhood'].apply(lambda x: map_df1_to_df2.get(x, None))
df1["df1_to_df3_map"] = df1['NYC Neighborhood'].apply(lambda x: map_df1_to_df3.get(x, None))

# Create a new data frame which merges the three data frames into one.
merged = pd.merge(df1, df2, left_on='df1_to_df2_map', right_on='Location')
merged = pd.merge(merged, df3, left_on='df1_to_df3_map', right_on='Location')

# Create a new data frame only keeping the relevant columns from the merged data frame
comparison_df = merged[["NYC Neighborhood", "Walkability Score", "Obesity Rate %", "Poverty Rate %"]]

# Print the new data frame
print(comparison_df)
# Out:
#                       NYC Neighborhood  Walkability Score  Obesity Rate %  \
# 0                Bayside - Little Neck                  2            12.0
# 1   Bedford Stuyvesant - Crown Heights                  6            22.1
# 2              Bensonhurst - Bay Ridge                  4            18.1
# 3                         Borough Park                  4            17.7
# 4                 Canarsie - Flatlands                  3            21.3
# 5                    Chelsea - Clinton                 11            12.6
# 6        Coney Island - Sheepshead Bay                  4            17.3
# 7             East Flatbush - Flatbush                  4            21.2
# 8                          East Harlem                  6            24.6
# 9                        East New York                  5            23.8
# 10                Flushing - Clearview                  2            15.4
# 11                       Fresh Meadows                  3            16.1
# ...

# %% [markdown]
# ## ✅Design Decisions

# %% [markdown]
# # ✅Discussion
# --------------------------

# %% [markdown]
# When considering the interests of a stakeholder in the context of our project exploring the relationship between walkability and well-being in urban areas, the focus would typically be on aspects that have direct implications for policy, urban planning, economic benefits, and public health. Here are the topics from the list that would likely be most relevant to a stakeholder:
#
#
# 1. Impact on Poverty and Economic Status: Stakeholders would be interested in understanding how walkability correlates with economic factors like poverty rates. Improved walkability could enhance job access and economic opportunities, which is crucial for urban development and social equity.
#
# 2. Access to Healthcare: The relationship between walkability and access to healthcare is vital for stakeholders, as it affects public health outcomes and the healthcare system's efficiency.
#
# 3. Walkability and Physical Health: The link between walkability and physical health, including obesity rates, is important. Stakeholders would be keen on this due to its implications for public health and associated healthcare costs.
#
# 4. Urban Planning and Policy Implications: This is perhaps the most crucial area for stakeholders. The findings could influence urban planning and policy decisions, aiming to improve walkability and, by extension, residents' well-being.
#
# 5. Comparative Analysis Across Neighborhoods: Understanding how different neighborhoods vary in walkability and its impacts can help stakeholders identify areas needing improvement and target interventions more effectively.
#
# 6. Socioeconomic Factors: The interaction between walkability and socioeconomic factors is important for understanding the broader social implications and for addressing equity issues in urban development.
#
# 7. Generalizability of Findings: Stakeholders would be interested in how the findings from New York City could be applied to other urban settings, determining the scalability and applicability of any policies or urban planning strategies.
#
# 8. Limitations and Future Research Directions: Knowledge of our study's limitations and potential future research directions can help stakeholders assess the robustness of the findings and plan for further investigations.

# %% [markdown]
# ### ✅The Relationship Between Walkability and Poverty Rate in NYC Neighborhoods

# %%
# Selecting relevant columns from the DataFrame for visualization
poverty_walkability = comparison_df[["NYC Neighborhood", "Walkability Score", "Poverty Rate %"]]

# Creating a scatter plot with the filtered dataset
plt.figure(figsize=(12, 8))
scatter = sns.scatterplot(data=poverty_walkability,
                          x='Walkability Score',     # x-axis represents Walkability Score
                          y='Poverty Rate %',        # y-axis represents Poverty Rate %
                          hue='NYC Neighborhood',    # Colors represent different NYC Neighborhoods
                          style='NYC Neighborhood',  # Distinguishes between neighborhoods with different markers
                          palette='rainbow',         # Color palette for better visibility
                          s=100)                     # Marker size

# Adding a legend with specified title and position
plt.legend(title='NYC Neighborhood', loc='upper right', bbox_to_anchor=(1.35, 1))

# Adding labels and title to the plot
plt.title('Relationship Between Walkability and Poverty Rates in Selected NYC Neighborhoods')
plt.xlabel('Average Walkability Score')
plt.ylabel('Average Poverty Rate (%)')

# Displaying grid on the plot for better readability
plt.grid(True)

# Showing the plot
plt.show()

# %% [markdown]
# Our chart is a visualization tool meant to explore and possibly identify patterns or correlations between the walkability of neighborhoods in NYC and the average poverty rates within those areas.
#
#
# **Data Points:**
#
# * Each dot on the scatter plot represents a different neighborhood in NYC. The colors of the dots correspond to the legend on the right side of the chart, which lists the neighborhoods. There are multiple colors used, and each color is distinct to a neighborhood, making it easy to identify on the graph. The positioning of each dot corresponds to the walkability score (on the X-axis) and the poverty rate (on the Y-axis) for that neighborhood.
#
#
# **Key Elements for Analysis**
#
# * The X-axis (horizontal) is labeled "Average Walkability Score," which suggests that walkability has been quantified into a score, likely based on factors such as the density of amenities, pedestrian friendliness, access to public transit, etc. The scale of this axis ranges from 0 to slightly above 12.
#
# * The Y-axis (vertical) is labeled "Average Poverty Rate (%)", which indicates the percentage of the population in poverty within each neighborhood. The scale on this axis ranges from 0% to slightly above 40%.
#
# * Legend: On the right, there is a color-coded legend that matches each dot's color to its corresponding neighborhood. For example, a red dot represents the Bayside - Little Neck neighborhood, while a dark green dot represents Hunts Point - Mott Haven. This legend is crucial for interpreting which dot corresponds to which neighborhood.
#
#
# **Key Observations**
#
# * The distribution of dots does not suggest a clear linear relationship between walkability and poverty rates; the data points are quite spread out across the chart.
#
# * Some neighborhoods with high walkability scores have low poverty rates, but there are also neighborhoods with high walkability scores that have moderate to high poverty rates.
#
# * Conversely, some neighborhoods with low walkability scores have low poverty rates, while others have high poverty rates.

# %% [markdown]
# ### ✅The Relationship Between Walkability and Obesity Rates in NYC Neighborhoods

# %%
# Selecting relevant columns from the DataFrame for visualization
obesity_walkability = comparison_df[["NYC Neighborhood", "Walkability Score", "Obesity Rate %"]]

# Creating a scatter plot with the filtered dataset
plt.figure(figsize=(12, 8))
scatter = sns.scatterplot(data=obesity_walkability,
                          x='Walkability Score',     # x-axis represents Walkability Score
                          y='Obesity Rate %',        # y-axis represents Obesity Rate %
                          hue='NYC Neighborhood',    # Colors represent different NYC Neighborhoods
                          style='NYC Neighborhood',  # Distinguishes between neighborhoods with different markers
                          palette='rainbow',         # Color palette for better visibility
                          s=100)                     # Marker size

# Adding a legend with specified title and position
plt.legend(title='NYC Neighborhood', loc='upper right', bbox_to_anchor=(1.35, 1))

# Adding labels and title to the plot
plt.title('Relationship Between Walkability and Obesity Rates in Selected NYC Neighborhoods')
plt.xlabel('Average Walkability Score')
plt.ylabel('Average Obesity Rate (%)')

# Displaying grid on the plot for better readability
plt.grid(True)

# Showing the plot
plt.show()

# %% [markdown]
#  Our chart was designed to investigate the potential link between the walkability of NYC neighborhoods and their obesity rates. This indicates that the chart aims to explore the correlation between how pedestrian-friendly an area is and the prevalence of obesity among its residents.
#
# **Data Points:**
#
# * There are numerous colored dots scattered across the plot, with each dot representing a different NYC neighborhood. The location of each dot corresponds to the neighborhood's average walkability score (x-coordinate) and obesity rate (y-coordinate).
#
#
#  **Key Elements for Analysis**
#
#  * X-axis: Labeled "Average Walkability Score", it represents the walkability of each neighborhood, measured on a scale presumably from 0 to just above 12, suggesting a scoring system that assesses the ease of walking in the neighborhood.
#
#  * Y-axis: Labeled "Average Obesity Rate (%)", it denotes the obesity rate in each neighborhood, displayed as a percentage. The scale extends from 0 to 25%.
#
#
#
#  **Key Observations**
#
# * To the right of the scatter plot, there is a color-coded legend that matches the colors of the dots to their respective neighborhoods, such as a pink dot for Bayside - Little Neck, a dark blue dot for Bedford Stuyvesant - Crown Heights, etc. This key helps in identifying each neighborhood on the plot.
#
# * There is a wide dispersion of dots across the walkability scores, suggesting varying levels of walkability across neighborhoods.
#
# * The obesity rates fluctuate and do not show a clear pattern or correlation with walkability scores—neither a clear positive nor negative trend is observable from the chart alone.
#
# * Some neighborhoods with high walkability scores have lower obesity rates, but others with similar scores have higher obesity rates.
#
# * Similarly, neighborhoods with low walkability scores show a range of obesity rates, indicating that factors other than walkability might influence obesity rates.

# %% [markdown]
# ### ✅Target Audience

# %% [markdown]
# Urban planners, community developers, policy makers, and the general public. People who are interested in understanding the correlations between walkability, health, and happiness to inform urban planning decisions.

# %% [markdown]
# Urban planners, community developers, and policymakers are always working to improve urban livability and sustainability. The target audience emphasizes the intrinsic link between urban planning, health, and general well-being through networks and programs like HEALTHY CITIES, Virginia Blueprint for Livable Communities, and the New Urbanism movement. For instance, the HEALTHY CITIES network embodies a cross-sectoral approach that might be enhanced by evidence-based insights on walkability, health, and happiness. It aims to integrate urban design initiatives with health-promoting objectives. As part of the Virginia Blueprint for Livable Communities effort, community developers and urban planners work to create livable, age-friendly environments throughout Virginia.
#
# These professionals can advocate for pedestrian-friendly urban designs, thereby boosting physical exercise, social contact, and improved quality of life, on the basis of the insights from research on walkability, health, and happiness. The New Urbanism movement, which promotes walkable communities, might use the results of this research to support the many advantages of walkable urban forms on a larger scale. This includes not only health and happiness but also economic vitality and environmental sustainability.
#
# Furthermore, this research could be used by decision-makers and urban planners at organizations like the Institute for Transportation and Development Policy and the MIT City Form Lab to improve urban policies, development standards, and design guidelines. This would help to create cities that are supportive of a community's overall well-being. All of these stakeholders can contribute to the development of lively, healthy, and happy urban communities by making informed, significant decisions in urban planning undertakings through a nuanced understanding of the relationships between walkability, health, and happiness.

# %% [markdown]
# ### ✅What is the overall design?

# %% [markdown]
# # ✅Results
# -------------------

# %% [markdown]
# # ✅Conclusions
# ------------------------

# %% [markdown]
# Metrics and Performance Measures
#
# * In our analysis, we rigorously evaluated the correlation between walkability and various well-being indicators. We employed metrics such as the Walk Score to quantify neighborhood walkability. This score considers pedestrian friendliness, access to amenities, and road attributes. For well-being indicators, we analyzed data on obesity rates, mental health statistics, and access to healthcare.
#
# Discussion of Challenges and Experimental Results
#
# * Our project encountered several challenges, notably in data collection and establishing causality. We found that while higher walkability often correlated with improved well-being, there were outliers. Some highly walkable areas still faced significant health challenges, suggesting that factors beyond walkability, such as socioeconomic status, also play a crucial role.
#
# Key Findings:
#
#
# Future Research:
#
# While our study provides foundational insights, ongoing research is crucial to further understand the nuances of the walkability-well-being relationship. Future work could delve deeper into the interplay between walkability and specific well-being aspects, such as mental health or community engagement. Longitudinal studies would be particularly valuable in understanding how changes in urban design impact well-being over time. Additionally, expanding the study to include other diverse urban environments could provide a more comprehensive understanding of these dynamics on a global scale.
#
#
# Evaluation Strategy:
#
# * Comparative Analysis:
#
#   * Performed a detailed comparative analysis across New York City neighborhoods to identify correlations between walkability and its effects on community well-being factors like poverty and obesity.
#
# Our research contributes significantly to the understanding of urban factors influencing well-being, advocating for a paradigm shift in urban planning towards creating more pedestrian-friendly communities. Our outcomes offer a strong foundation for policies and initiatives aimed at elevating the quality of life in urban settings.

# %% [markdown]
# # 🚧References🚧
# ---------------------

# %% [markdown]
# 1. [*HEALTHY CITIES Network*](https://baxcompany.com/healthy-cities/): The goal of a network made up of municipal and planning agencies is to promote health through a cross-sectoral and collaborative approach to urban planning.
#
# 1. [*Institute for Transportation and Development Policy*](https://www.itdp.org/2018/02/07/pedestrians-first-walkability-tool/#:~:text=With%20the%20urban%20share%20of,Tools%20for%20a%20Walkable%20City): This institute introduced a tool called "Pedestrians First" to help various stakeholders including city planners and NGOs to make cities more walkable, indicating a network of professionals focused on urban walkability​
#
# 1. [*Virginia Blueprint for Livable Communities*](https://www.dars.virginia.gov/vblc/#:~:text=In%20efforts%20to%20support%20the,The%20intent%20of%20this): An initiative that brings together citizens and state agency representatives to develop a blueprint for creating livable communities in Virginia. The website has various resources and may connect you to local planners and community developers interested in your topics of interest
#
# 1. [*MIT City Form Lab*](https://www.mmi.mit.edu/areas/Urban-Planning%2C-Design-and-Policy#:~:text=The%20City%20Form%20Lab%20at,solutions%20for%20contemporary%20urban%20challenges): This lab focuses on urban design, planning, and real-estate research, potentially housing a network of professionals interested in urban planning and design.
#
# 1. [*New Urbanism Movement*](https://en.wikipedia.org/wiki/New_Urbanism): An urban design movement promoting walkable neighborhoods, and it could have a community of professionals advocating for environmentally friendly urban planning practices.
#
# 1. [*National Walkability Index*](https://www.epa.gov/smartgrowth/national-walkability-index-user-guide-and-methodology#:~:text=This%20User%20Guide%20provides%20methodology,63%20MB%2C%202021): This index developed by the EPA could be a resource to find metrics and potentially connect with professionals interested in urban walkability​.

# %% [markdown]
# Potential dataset to explore: https://a816-dohbesp.nyc.gov/IndicatorPublic/beta/data-explorer/walking-driving-and-cycling/?id=2415#display=summary
